# %%
#Import dependency for the database import
import pandas as pd
from sqlalchemy import create_engine

# %%
#import database password
from config1 import db_password

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/water_potability"

# %%
#setup the database string
engine = create_engine(db_string)

# %%
water_inventory = pd.read_sql('SELECT * FROM completed_safe_water_df', engine)

# %%
water_inventory
# Out:
#       index        ph    hardness       solids  chloramines     sulfate  \
# 0         0  7.080795  204.890456  20791.31898     7.300212  368.516441
# 1         1  3.716080  129.422921  18630.05786     6.635246    7.080795
# 2         2  8.099124  224.236259  19909.54173     9.275884    7.080795
# 3         3  8.316766  214.373394  22018.41744     8.059332  356.886136
# 4         4  9.092223  181.101509  17978.98634     6.546600  310.135738
# ...     ...       ...         ...          ...          ...         ...
# 3271   3271  4.668102  193.681736  47580.99160     7.166639  359.948574
# 3272   3272  7.808856  193.553212  17329.80216     8.061362    7.080795
# 3273   3273  9.419510  175.762646  33155.57822     7.350233    7.080795
# 3274   3274  5.126763  230.603758  11983.86938     6.303357    7.080795
# 3275   3275  7.874671  195.102299  17404.17706     7.509306    7.080795
#
#       conductivity  organic_carbon  trihalomethanes  turbidity  potability
# ...
